# %% [markdown]
# <a href="https://colab.research.google.com/github/Deepeck05/New-github/blob/main/AIcls2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df= pd.read_csv('application_record.csv')

# %%
df.head()
# Out:
#         ID CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  CNT_CHILDREN  \
# 0  5008804           M            Y               Y             0
# 1  5008805           M            Y               Y             0
# 2  5008806           M            Y               Y             0
# 3  5008808           F            N               Y             0
# 4  5008809           F            N               Y             0
#
#    AMT_INCOME_TOTAL      NAME_INCOME_TYPE            NAME_EDUCATION_TYPE  \
# 0          427500.0               Working               Higher education
# 1          427500.0               Working               Higher education
# 2          112500.0               Working  Secondary / secondary special
# 3          270000.0  Commercial associate  Secondary / secondary special
# 4          270000.0  Commercial associate  Secondary / secondary special
#
#      NAME_FAMILY_STATUS  NAME_HOUSING_TYPE  DAYS_BIRTH  DAYS_EMPLOYED  \
# ...

# %%
df.tail()
# Out:
#             ID CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  CNT_CHILDREN  \
# 59245  5185824           F            N               Y             0
# 59246  5185825           F            N               Y             0
# 59247  5526636           F            N               Y             0
# 59248  5185829           F            N               Y             0
# 59249  5185830           F            N               Y             0
#
#        AMT_INCOME_TOTAL NAME_INCOME_TYPE            NAME_EDUCATION_TYPE  \
# 59245          135000.0        Pensioner  Secondary / secondary special
# 59246          135000.0        Pensioner  Secondary / secondary special
# 59247          135000.0        Pensioner  Secondary / secondary special
# 59248          112500.0          Working  Secondary / secondary special
# 59249          112500.0          Working  Secondary / secondary special
#
#       NAME_FAMILY_STATUS  NAME_HOUSING_TYPE  DAYS_BIRTH  DAYS_EMPLOYED  \
# ...

# %%
df.loc[0:2]
# Out:
#         ID CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  CNT_CHILDREN  \
# 0  5008804           M            Y               Y             0
# 1  5008805           M            Y               Y             0
# 2  5008806           M            Y               Y             0
#
#    AMT_INCOME_TOTAL NAME_INCOME_TYPE            NAME_EDUCATION_TYPE  \
# 0          427500.0          Working               Higher education
# 1          427500.0          Working               Higher education
# 2          112500.0          Working  Secondary / secondary special
#
#   NAME_FAMILY_STATUS  NAME_HOUSING_TYPE  DAYS_BIRTH  DAYS_EMPLOYED  \
# 0     Civil marriage   Rented apartment      -12005          -4542
# 1     Civil marriage   Rented apartment      -12005          -4542
# 2            Married  House / apartment      -21474          -1134
#
#    FLAG_MOBIL  FLAG_WORK_PHONE  FLAG_PHONE  FLAG_EMAIL OCCUPATION_TYPE  \
# 0           1                1           0           0             NaN
# ...

# %%
df.loc[0, ["ID","CODE_GENDER"]]
# Out:
# ID             5008804
# CODE_GENDER          M
# Name: 0, dtype: object

# %%
df.loc[0:,[ "ID","CODE_GENDER"]]
# Out:
#              ID CODE_GENDER
# 0       5008804           M
# 1       5008805           M
# 2       5008806           M
# 3       5008808           F
# 4       5008809           F
# ...         ...         ...
# 438552  6840104           M
# 438553  6840222           F
# 438554  6841878           F
# 438555  6842765           F
# 438556  6842885           F
#
# [438557 rows x 2 columns]

# %%
df.iloc[0:5]
# Out:
#         ID CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  CNT_CHILDREN  \
# 0  5008804           M            Y               Y             0
# 1  5008805           M            Y               Y             0
# 2  5008806           M            Y               Y             0
# 3  5008808           F            N               Y             0
# 4  5008809           F            N               Y             0
#
#    AMT_INCOME_TOTAL      NAME_INCOME_TYPE            NAME_EDUCATION_TYPE  \
# 0          427500.0               Working               Higher education
# 1          427500.0               Working               Higher education
# 2          112500.0               Working  Secondary / secondary special
# 3          270000.0  Commercial associate  Secondary / secondary special
# 4          270000.0  Commercial associate  Secondary / secondary special
#
#      NAME_FAMILY_STATUS  NAME_HOUSING_TYPE  DAYS_BIRTH  DAYS_EMPLOYED  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59250 entries, 0 to 59249
# Data columns (total 18 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ID                   59250 non-null  int64
#  1   CODE_GENDER          59250 non-null  object
#  2   FLAG_OWN_CAR         59250 non-null  object
#  3   FLAG_OWN_REALTY      59250 non-null  object
#  4   CNT_CHILDREN         59250 non-null  int64
#  5   AMT_INCOME_TOTAL     59250 non-null  float64
#  6   NAME_INCOME_TYPE     59250 non-null  object
#  7   NAME_EDUCATION_TYPE  59250 non-null  object
#  8   NAME_FAMILY_STATUS   59250 non-null  object
#  9   NAME_HOUSING_TYPE    59250 non-null  object
#  10  DAYS_BIRTH           59250 non-null  int64
#  11  DAYS_EMPLOYED        59250 non-null  int64
#  12  FLAG_MOBIL           59250 non-null  int64
#  13  FLAG_WORK_PHONE      59250 non-null  int64
#  14  FLAG_PHONE           59250 non-null  int64
# ...

# %%
df.describe()
# Out:
#                  ID  CNT_CHILDREN  AMT_INCOME_TOTAL    DAYS_BIRTH  \
# count  5.925000e+04  59250.000000      5.925000e+04  59250.000000
# mean   5.322382e+06      0.428962      1.864894e+05 -16097.542380
# std    4.544716e+05      0.736350      1.075018e+05   4183.178977
# min    5.008804e+06      0.000000      2.700000e+04 -25201.000000
# 25%    5.062246e+06      0.000000      1.215000e+05 -19589.750000
# 50%    5.118638e+06      0.000000      1.575000e+05 -15686.500000
# 75%    5.278735e+06      1.000000      2.250000e+05 -12606.000000
# max    6.836568e+06     19.000000      3.825000e+06  -7489.000000
#
#        DAYS_EMPLOYED  FLAG_MOBIL  FLAG_WORK_PHONE    FLAG_PHONE    FLAG_EMAIL  \
# count   59250.000000     59250.0     59250.000000  59250.000000  59250.000000
# mean    62646.838650         1.0         0.212928      0.295460      0.089435
# std    140622.144361         0.0         0.409381      0.456253      0.285372
# ...

# %%
df.describe(include='all')
# Out:
#                   ID CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  CNT_CHILDREN  \
# count   5.925000e+04       59250        59250           59250  59250.000000
# unique           NaN           2            2               2           NaN
# top              NaN           F            N               Y           NaN
# freq             NaN       40214        37029           41144           NaN
# mean    5.322382e+06         NaN          NaN             NaN      0.428962
# std     4.544716e+05         NaN          NaN             NaN      0.736350
# min     5.008804e+06         NaN          NaN             NaN      0.000000
# 25%     5.062246e+06         NaN          NaN             NaN      0.000000
# 50%     5.118638e+06         NaN          NaN             NaN      0.000000
# 75%     5.278735e+06         NaN          NaN             NaN      1.000000
# max     6.836568e+06         NaN          NaN             NaN     19.000000
#
# ...

# %%
df.isnull()
# Out:
#           ID  CODE_GENDER  FLAG_OWN_CAR  FLAG_OWN_REALTY  CNT_CHILDREN  \
# 0      False        False         False            False         False
# 1      False        False         False            False         False
# 2      False        False         False            False         False
# 3      False        False         False            False         False
# 4      False        False         False            False         False
# ...      ...          ...           ...              ...           ...
# 59245  False        False         False            False         False
# 59246  False        False         False            False         False
# 59247  False        False         False            False         False
# 59248  False        False         False            False         False
# 59249  False        False         False            False         False
#
#        AMT_INCOME_TOTAL  NAME_INCOME_TYPE  NAME_EDUCATION_TYPE  \
# ...

# %%
df['ID'].isnull()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 59245    False
# 59246    False
# 59247    False
# 59248    False
# 59249    False
# Name: ID, Length: 59250, dtype: bool

# %%
pd.isnull(df.loc[0:2,[ "ID","CODE_GENDER"]])
# Out:
#       ID  CODE_GENDER
# 0  False        False
# 1  False        False
# 2  False        False

# %%
df.dtypes
# Out:
# ID                       int64
# CODE_GENDER             object
# FLAG_OWN_CAR            object
# FLAG_OWN_REALTY         object
# CNT_CHILDREN             int64
# AMT_INCOME_TOTAL       float64
# NAME_INCOME_TYPE        object
# NAME_EDUCATION_TYPE     object
# NAME_FAMILY_STATUS      object
# NAME_HOUSING_TYPE       object
# DAYS_BIRTH               int64
# DAYS_EMPLOYED            int64
# FLAG_MOBIL               int64
# FLAG_WORK_PHONE          int64
# FLAG_PHONE               int64
# FLAG_EMAIL               int64
# OCCUPATION_TYPE         object
# CNT_FAM_MEMBERS        float64
# dtype: object

# %%
df=df.fillna('unknow')

# %%
df.isnull().sum()
# Out:
# ID                     0
# CODE_GENDER            0
# FLAG_OWN_CAR           0
# FLAG_OWN_REALTY        0
# CNT_CHILDREN           0
# AMT_INCOME_TOTAL       0
# NAME_INCOME_TYPE       0
# NAME_EDUCATION_TYPE    0
# NAME_FAMILY_STATUS     0
# NAME_HOUSING_TYPE      0
# DAYS_BIRTH             0
# DAYS_EMPLOYED          0
# FLAG_MOBIL             0
# FLAG_WORK_PHONE        0
# FLAG_PHONE             0
# FLAG_EMAIL             0
# OCCUPATION_TYPE        0
# CNT_FAM_MEMBERS        0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.duplicated(subset=['ID','CODE_GENDER'])
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 438552    False
# 438553    False
# 438554    False
# 438555    False
# 438556    False
# Length: 438557, dtype: bool

# %%
df.duplicated(subset=['ID']).sum()
# Out:
# np.int64(47)

# %%
import matplotlib.pyplot as plt

# %%
df.groupby("NAME_INCOME_TYPE")["ID"].count().plot(kind="bar")
# Out:
# <Axes: xlabel='NAME_INCOME_TYPE'>

# %%
#ple plot
df.groupby("OCCUPATION_TYPE")["ID"].count().plot(kind='pie')
plt
# Out:
# <Axes: ylabel='ID'>

# %%
#vishualing from seaborn library
import seaborn as sns
sns.countplot(x='NAME_INCOME_TYPE',data=df)
# Out:
# <Axes: xlabel='NAME_INCOME_TYPE', ylabel='count'>
